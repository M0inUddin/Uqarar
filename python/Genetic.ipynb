# %%
semester1 = {
    'SC1201': {'Code': 'SC1201', 'Title': 'Applied Physics', 'Credit Hours': '3+0', 'Pre-Requisite': 'FRESHMAN STANDING'},
    'SC1001': {'Code': 'SC1001', 'Title': 'Calculus & Analytic Geometry', 'Credit Hours': '3+0', 'Pre-Requisite': 'FRESHMAN STANDING'},
    'HU1002': {'Code': 'HU1002', 'Title': 'English Composition & Comprehension', 'Credit Hours': '3+0', 'Pre-Requisite': 'FRESHMAN STANDING'},
    'CS1501': {'Code': 'CS1501', 'Title': 'Introduction to Information and Communication Technologies', 'Credit Hours': '1+1', 'Pre-Requisite': 'FRESHMAN STANDING'},
    'CS1001': {'Code': 'CS1001', 'Title': 'Programming Fundamentals', 'Credit Hours': '3+1', 'Pre-Requisite': 'FRESHMAN STANDING'}
}

semester2 = {
    'HU1003': {'Code': 'HU1003', 'Title': 'Communication & Presentation Skills', 'Credit Hours': '3+0', 'Pre-Requisite': 'FRESHMAN STANDING'},
    'CS1502': {'Code': 'CS1502', 'Title': 'Digital Logic and Design', 'Credit Hours': '3+1', 'Pre-Requisite': 'FRESHMAN STANDING'},
    'HU1101': {'Code': 'HU1101', 'Title': 'Islamic Studies', 'Credit Hours': '2+0', 'Pre-Requisite': 'FRESHMAN STANDING'},
    'SC1002': {'Code': 'SC1002', 'Title': 'Multivariate Calculus', 'Credit Hours': '2+0', 'Pre-Requisite': 'SC1001'},
    'HU1102': {'Code': 'HU1102', 'Title': 'Pakistan Studies', 'Credit Hours': '2+0', 'Pre-Requisite': 'FRESHMAN STANDING'},
    'CS1002': {'Code': 'CS1002', 'Title': 'Programming Techniques', 'Credit Hours': '1+1', 'Pre-Requisite': 'CS1001'}
}

semester3 = {
    'CS2503': {'Code': 'CS2503', 'Title': 'Computer Organization & Assembly Language', 'Credit Hours': '3+1', 'Pre-Requisite': 'SPM'},
    'CS2003': {'Code': 'CS2003', 'Title': 'Data Structure and Algorithms', 'Credit Hours': '3+1', 'Pre-Requisite': 'CS1001'},
    'SC2003': {'Code': 'SC2003', 'Title': 'Differential Equations', 'Credit Hours': '3+0', 'Pre-Requisite': 'SC1001'},
    'HU1103': {'Code': 'HU1103', 'Title': 'Pakistan Studies', 'Credit Hours': '2+0', 'Pre-Requisite': 'FRESHMAN STANDING'},
    'CS2301': {'Code': 'CS2301', 'Title': 'Discrete Structures', 'Credit Hours': '3+0', 'Pre-Requisite': 'FRESHMAN STANDING'},
    'CS2004': {'Code': 'CS2004', 'Title': 'Object Oriented Programming', 'Credit Hours': '3+1', 'Pre-Requisite': 'CS1001'}
}

semester4 = {
    'CS2201': {'Code': 'CS2201', 'Title': 'Introduction to Database Systems', 'Credit Hours': '3+1', 'Pre-Requisite': 'CS2003'},
    'CS2504': {'Code': 'CS2504', 'Title': 'Operating Systems', 'Credit Hours': '3+1', 'Pre-Requisite': 'CS2003'},
    'SC2004': {'Code': 'SC2004', 'Title': 'Probability and Statistics', 'Credit Hours': '3+0', 'Pre-Requisite': 'SOPHOMORE STANDING'},
    'CS2101': {'Code': 'CS2101', 'Title': 'Software Engineering', 'Credit Hours': '3+0', 'Pre-Requisite': 'SOPHOMORE STANDING'}
}

semester5 = {
    'CS4303': {'Code': 'CS4303', 'Title': 'Artificial Intelligence', 'Credit Hours': '3+1', 'Pre-Requisite': 'CS2003'},
    'CS3005': {'Code': 'CS3005', 'Title': 'Design & Analysis of Algorithms', 'Credit Hours': '3+0', 'Pre-Requisite': 'CS2003'},
    'SC3005': {'Code': 'SC3005', 'Title': 'Linear Algebra', 'Credit Hours': '3+0', 'Pre-Requisite': 'JUNIOR STANDING'},
    'CS3302': {'Code': 'CS3302', 'Title': 'Theory of Automata and Formal Languages', 'Credit Hours': '3+0', 'Pre-Requisite': 'CS2301'}
}

semester6 = {
    'CS3401': {'Code': 'CS3401', 'Title': 'Computer Communication and Networks', 'Credit Hours': '3+1', 'Pre-Requisite': 'JUNIOR STANDING'},
    'SC3006': {'Code': 'SC3006', 'Title': 'Numerical Computing', 'Credit Hours': '2+0', 'Pre-Requisite': 'JUNIOR STANDING'},
    'HU3004': {'Code': 'HU3004', 'Title': 'Technical & Business Writing', 'Credit Hours': '3+0', 'Pre-Requisite': 'JUNIOR STANDING'}
}

semester7 = {
    'CS4006': {'Code': 'CS4006', 'Title': 'Compiler Construction', 'Credit Hours': '3+0', 'Pre-Requisite': 'CS3302'},
    'CS4405': {'Code': 'CS4405', 'Title': 'Parallel & Distributed Computing', 'Credit Hours': '3+0', 'Pre-Requisite': 'CS2504'},
    'CS4111': {'Code': 'CS4111', 'Title': 'Senior Design Project-I', 'Credit Hours': '2+0', 'Pre-Requisite': 'SC'}
}

semester8 = {
    'CS4406': {'Code': 'CS4406', 'Title': 'Information Security', 'Credit Hours': '3+0', 'Pre-Requisite': 'Senior Standing'},
    'CS4112': {'Code': 'CS4112', 'Title': 'Senior Design Project-II', 'Credit Hours': '4+0', 'Pre-Requisite': 'CS4111'}
}

curriculum = {
    'semester1': semester1,
    'semester2': semester2,
    'semester3': semester3,
    'semester4': semester4,
    'semester5': semester5,
    'semester6': semester6,
    'semester7': semester7,
    'semester8': semester8
}

# %%
import random
# Getting user input
current_semester = 3
failed_courses = ['CS2003','SC1002','CS2503']

# %%
import random

semester1 = {
    'SC1201': {'Code': 'SC1201', 'Title': 'Applied Physics', 'Credit Hour': '3+0', 'Pre-Requisite': 'FRESHMAN STANDING'},
    'SC1001': {'Code': 'SC1001', 'Title': 'Calculus & Analytic Geometry', 'Credit Hour': '3+0', 'Pre-Requisite': 'FRESHMAN STANDING'},
    'HU1002': {'Code': 'HU1002', 'Title': 'English Composition & Comprehension', 'Credit Hour': '3+0', 'Pre-Requisite': 'FRESHMAN STANDING'},
    'CS1501': {'Code': 'CS1501', 'Title': 'Introduction to Information and Communication Technologies', 'Credit Hour': '1+1', 'Pre-Requisite': 'FRESHMAN STANDING'},
    'CS1001': {'Code': 'CS1001', 'Title': 'Programming Fundamentals', 'Credit Hour': '3+1', 'Pre-Requisite': 'FRESHMAN STANDING'}
}

semester2 = {
    'HU1003': {'Code': 'HU1003', 'Title': 'Communication & Presentation Skills', 'Credit Hour': '3+0', 'Pre-Requisite': 'FRESHMAN STANDING'},
    'CS1502': {'Code': 'CS1502', 'Title': 'Digital Logic and Design', 'Credit Hour': '3+1', 'Pre-Requisite': 'FRESHMAN STANDING'},
    'HU1101': {'Code': 'HU1101', 'Title': 'Islamic Studies', 'Credit Hour': '2+0', 'Pre-Requisite': 'FRESHMAN STANDING'},
    'SC1002': {'Code': 'SC1002', 'Title': 'Multivariate Calculus', 'Credit Hour': '2+0', 'Pre-Requisite': 'SC1001'},
    'HU1102': {'Code': 'HU1102', 'Title': 'Pakistan Studies', 'Credit Hour': '2+0', 'Pre-Requisite': 'FRESHMAN STANDING'},
    'CS1002': {'Code': 'CS1002', 'Title': 'Programming Techniques', 'Credit Hour': '1+1', 'Pre-Requisite': 'CS1001'}
}

semester3 = {
    'CS2503': {'Code': 'CS2503', 'Title': 'Computer Organization & Assembly Language', 'Credit Hour': '3+1', 'Pre-Requisite': 'SPM'},
    'CS2003': {'Code': 'CS2003', 'Title': 'Data Structure and Algorithms', 'Credit Hour': '3+1', 'Pre-Requisite': 'CS1001'},
    'SC2003': {'Code': 'SC2003', 'Title': 'Differential Equations', 'Credit Hour': '3+0', 'Pre-Requisite': 'SC1001'},
    'HU1103': {'Code': 'HU1103', 'Title': 'Pakistan Studies', 'Credit Hour': '2', 'Pre-Requisite': 'FRESHMAN STANDING'},
    'CS2301': {'Code': 'CS2301', 'Title': 'Discrete Structures', 'Credit Hour': '3+0', 'Pre-Requisite': 'FRESHMAN STANDING'},
    'CS2004': {'Code': 'CS2004', 'Title': 'Object Oriented Programming', 'Credit Hour': '3+1', 'Pre-Requisite': 'CS1001'}
}

semester4 = {
    'CS2201': {'Code': 'CS2201', 'Title': 'Introduction to Database Systems', 'Credit Hour': '3+1', 'Pre-Requisite': 'CS2003'},
    'CS2504': {'Code': 'CS2504', 'Title': 'Operating Systems', 'Credit Hour': '3+1', 'Pre-Requisite': 'CS2003'},
    'SC2004': {'Code': 'SC2004', 'Title': 'Probability and Statistics', 'Credit Hour': '3+0', 'Pre-Requisite': 'SOPHOMORE STANDING'},
    'CS2101': {'Code': 'CS2101', 'Title': 'Software Engineering', 'Credit Hour': '3+0', 'Pre-Requisite': 'SOPHOMORE STANDING'}
}

semester5 = {
    'CS4303': {'Code': 'CS4303', 'Title': 'Artificial Intelligence', 'Credit Hours': '3+1', 'Pre-Requisite': 'CS2003'},
    'CS3005': {'Code': 'CS3005', 'Title': 'Design & Analysis of Algorithms', 'Credit Hours': '3+0', 'Pre-Requisite': 'CS2003'},
    'SC3005': {'Code': 'SC3005', 'Title': 'Linear Algebra', 'Credit Hours': '3+0', 'Pre-Requisite': 'JUNIOR STANDING'},
    'CS3302': {'Code': 'CS3302', 'Title': 'Theory of Automata and Formal Languages', 'Credit Hours': '3+0', 'Pre-Requisite': 'CS2301'}
}

semester6 = {
    'CS3401': {'Code': 'CS3401', 'Title': 'Computer Communication and Networks', 'Credit Hours': '3+1', 'Pre-Requisite': 'JUNIOR STANDING'},
    'SC3006': {'Code': 'SC3006', 'Title': 'Numerical Computing', 'Credit Hours': '2+0', 'Pre-Requisite': 'JUNIOR STANDING'},
    'HU3004': {'Code': 'HU3004', 'Title': 'Technical & Business Writing', 'Credit Hours': '3+0', 'Pre-Requisite': 'JUNIOR STANDING'}
}

semester7 = {
    'CS4006': {'Code': 'CS4006', 'Title': 'Compiler Construction', 'Credit Hours': '3+0', 'Pre-Requisite': 'CS3302'},
    'CS4405': {'Code': 'CS4405', 'Title': 'Parallel & Distributed Computing', 'Credit Hours': '3+0', 'Pre-Requisite': 'CS2504'},
    'CS4111': {'Code': 'CS4111', 'Title': 'Senior Design Project-I', 'Credit Hours': '2+0', 'Pre-Requisite': 'SC'}
}

semester8 = {
    'CS4406': {'Code': 'CS4406', 'Title': 'Information Security', 'Credit Hours': '3+0', 'Pre-Requisite': 'Senior Standing'},
    'CS4112': {'Code': 'CS4112', 'Title': 'Senior Design Project-II', 'Credit Hours': '4+0', 'Pre-Requisite': 'CS4111'}
}

curriculum = {
    'semester1': semester1,
    'semester2': semester2,
    'semester3': semester3,
    'semester4': semester4,
    'semester5': semester5,
    'semester6': semester6,
    'semester7': semester7,
    'semester8': semester8
}

def calculate_total_credit_hours(course_plan):
    total_credit_hours = 0
    for semester in course_plan:
        for course in course_plan[semester]:
            credit_hour = int(curriculum[semester][course]['Credit Hour'].split('+')[0])
            total_credit_hours += credit_hour
    return total_credit_hours

def is_course_valid(course_code, current_semester, course_plan):
    for semester in course_plan:
        for course in course_plan[semester]:
            if curriculum[current_semester][course]['Pre-Requisite'] == course_code:
                return False
    return True

def generate_next_semester(current_semester, course_plan):
    courses_available = list(curriculum[f'semester{current_semester+1}'].keys())
    next_semester = f'semester{current_semester+1}'
    next_semester_plan = []
    
    for course in courses_available:
        if is_course_valid(course, next_semester, course_plan):
            next_semester_plan.append(course)
        if len(next_semester_plan) == 19:
            break
    
    return next_semester_plan

def genetic_algorithm(current_semester, failed_courses, num_population=100, num_generations=50):
    best_course_plan = None
    best_credit_hours = float('inf')
    
    for _ in range(num_generations):
        population = []
        
        for _ in range(num_population):
            course_plan = {f'semester{i}': [] for i in range(1, current_semester+1)}
            for course in failed_courses:
                course_plan[f'semester{current_semester}'].append(course)
            
            for i in range(current_semester, 8):
                next_semester_plan = generate_next_semester(i, course_plan)
                course_plan[f'semester{i+1}'] = next_semester_plan
                credit_hours = calculate_total_credit_hours(course_plan)
                
                if credit_hours < best_credit_hours:
                    best_course_plan = course_plan.copy()
                    best_credit_hours = credit_hours
        
        current_semester += 1
    
    return best_course_plan

import random
# Getting user input
current_semester = 3
failed_courses = ['CS2003','SC1002','CS2503']
best_course_plan = genetic_algorithm(current_semester, failed_courses)
print(best_course_plan)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[82], line 128
#     126 current_semester = 3
#     127 failed_courses = ['CS2003','SC1002','CS2503']
# --> 128 best_course_plan = genetic_algorithm(current_semester, failed_courses)
#     129 print(best_course_plan)
#
# Cell In[82], line 112, in genetic_algorithm(current_semester, failed_courses, num_population, num_generations)
#     109     course_plan[f'semester{current_semester}'].append(course)
#     111 for i in range(current_semester, 8):
# --> 112     next_semester_plan = generate_next_semester(i, course_plan)
#     113     course_plan[f'semester{i+1}'] = next_semester_plan
#     114     credit_hours = calculate_total_credit_hours(course_plan)
#
# Cell In[82], line 92, in generate_next_semester(current_semester, course_plan)
#      89 next_semester_plan = []
#      91 for course in courses_available:
# ...
